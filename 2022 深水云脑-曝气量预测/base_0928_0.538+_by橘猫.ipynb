# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import gc

import warnings
warnings.simplefilter('ignore')

# %%
train = pd.read_csv('train_dataset.csv')
test = pd.read_csv('evaluation_public.csv')

train['isnull'] = train.iloc[:,1:].isnull().mean(axis = 1)
test['isnull'] = test.iloc[:,1:].isnull().mean(axis = 1)

data = pd.concat([train, test]).reset_index(drop=True)

data['time'] = pd.to_datetime(data['time'])
data['hour'] = data['time'].dt.hour
data['minute'] = data['time'].dt.minute
data['weekday'] = data['time'].dt.weekday
data['ts'] = data['hour']*60 + data['minute']

# %%
train = data.iloc[:140480].reset_index(drop = True)
test = data.iloc[140480:].reset_index(drop = True)

## 对比测试集每行样本的特征缺失比，选取特征缺失比率相识的
train = train[train['isnull']<0.15].reset_index(drop=True)

train['Label1_log'] = np.log1p(train['Label1'])
train['Label2_log'] = np.log1p(train['Label2'])


## 通过特征重要性、对抗验证、特征相关性，剔除了这7个特征，可能剔除错了也可能没剔除干净
feas = [f for f in train.columns if f not in ['time', 'Label1', 'Label2','Label1_log','Label2_log', 
                                              'B_QY_ORP','JS_TN',
                                              'CS_SW','MCCS_NH4','N_HYC_JS_DO','MCCS_NO3','JS_SW',
                                             ]]

train = train.dropna(subset=['Label1', 'Label2']).reset_index(drop=True)

x_train = train[feas]
x_test = test[feas]

# %%
def lgb_model(clf, train_x, train_y, test_x):
    folds = 10
    seed = 2222
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []
    test_pre = []
    Feass = pd.DataFrame()

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]

        train_matrix = clf.Dataset(trn_x, label=trn_y)
        valid_matrix = clf.Dataset(val_x, label=val_y)

        fea = pd.DataFrame()

        params = {
            'learning_rate': 0.03,
            'boosting_type': 'gbdt',
            'objective': 'mse',
            'metric': 'mse',
            'verbose': -1,
            'seed': 2020,
            'n_jobs': -1,
            'max_depth':-1,
            'min_child_weight': 4,
            'num_leaves': 2 ** 4,
            'feature_fraction': 0.8,
            'bagging_fraction': 0.8,
            'bagging_freq': 4,
        }

        model = clf.train(params, train_matrix, num_boost_round=20000, valid_sets=[train_matrix, valid_matrix], 
                          categorical_feature =[] ,verbose_eval=1000,early_stopping_rounds=200)
        val_pred = model.predict(val_x, num_iteration=model.best_iteration)
        test_pred = model.predict(test_x, num_iteration=model.best_iteration)
        test_pre.append(test_pred)
        fea['feas'] = train_x.columns.tolist()
        fea['sorce'] = model.feature_importance()
        Feass = pd.concat([Feass,fea],axis = 0)
        print(list(sorted(zip(train_x.columns.tolist(), model.feature_importance()), key=lambda x: x[1], reverse=True))[:20])
            
            
        train[valid_index] = val_pred
        test = test_pred
        cv_scores.append(np.sqrt(mean_squared_error(np.expm1(val_y), np.expm1(val_pred))))
#         cv_scores.append(mean_squared_error(val_y, val_pred))
  
        print(cv_scores)
    test = sum(test_pre) / folds
    print("s_scotrainre_list:" , cv_scores)
    print("s_score_mean:" , np.mean(cv_scores))
    print("s_score_std:", np.std(cv_scores))

    return train, test, Feass, np.mean(cv_scores)

# %%
for idx, i in enumerate([[x_train, train['Label1_log'], x_test], [x_train, train['Label2_log'], x_test],]):
    locals()[f'lgb_train{idx}'], locals()[f'lgb_test{idx}'], \
    locals()[f'Feass{idx}'],     locals()[f'scores{idx}'] = lgb_model(lgb, i[0], i[1], i[2])
# Out:
# ************************************ 1 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00742455	valid_1's l2: 0.0154584
# [2000]	training's l2: 0.00504084	valid_1's l2: 0.0144517
# [3000]	training's l2: 0.00378112	valid_1's l2: 0.0138582
# [4000]	training's l2: 0.00299196	valid_1's l2: 0.0135563
# [5000]	training's l2: 0.00243645	valid_1's l2: 0.0134311
# [6000]	training's l2: 0.0020204	valid_1's l2: 0.0133132
# [7000]	training's l2: 0.00169659	valid_1's l2: 0.0131875
# Early stopping, best iteration is:
# [7369]	training's l2: 0.00159041	valid_1's l2: 0.0131449
# [('ts', 7765), ('N_QY_ORP', 6969), ('N_HYC_DO', 6785), ('B_HYC_DO', 6448), ('B_HYC_MLSS', 5879), ('N_HYC_MLSS', 5675), ('N_HYC_NH4', 5593), ('CS_COD', 5421), ('B_CS_MQ_SSLL', 5020), ('JS_COD', 5016), ('JS_LL', 4954), ('CS_TN', 4919), ('CS_NH3', 4898), ('B_HYC_XD', 4744), ('B_HYC_JS_DO', 4683), ('N_HYC_XD', 4513), ('JS_NH3', 4430), ('minute', 4196), ('CS_LL', 4118), ('N_CS_MQ_SSLL', 4011)]
# [1552.3658769487379]
# ************************************ 2 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00771038	valid_1's l2: 0.0120894
# [2000]	training's l2: 0.00514649	valid_1's l2: 0.0106106
# [3000]	training's l2: 0.0038476	valid_1's l2: 0.00997786
# [4000]	training's l2: 0.00305195	valid_1's l2: 0.0095997
# Early stopping, best iteration is:
# [4636]	training's l2: 0.00266749	valid_1's l2: 0.00945044
# [('ts', 5420), ('N_QY_ORP', 4947), ('N_HYC_DO', 4192), ('B_HYC_DO', 4074), ('CS_COD', 3950), ('B_HYC_MLSS', 3827), ('N_HYC_MLSS', 3728), ('N_HYC_NH4', 3583), ('JS_COD', 3390), ('CS_TN', 3213), ('CS_NH3', 3191), ('JS_NH3', 3184), ('B_CS_MQ_SSLL', 2854), ('JS_LL', 2735), ('N_HYC_XD', 2710), ('B_HYC_XD', 2698), ('B_HYC_JS_DO', 2581), ('minute', 2563), ('CS_LL', 2052), ('N_CS_MQ_SSLL', 1879)]
# [1552.3658769487379, 1388.0937554803734]
# ************************************ 3 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00766712	valid_1's l2: 0.00883515
# [2000]	training's l2: 0.00516896	valid_1's l2: 0.00770227
# [3000]	training's l2: 0.00386796	valid_1's l2: 0.00713626
# [4000]	training's l2: 0.00306499	valid_1's l2: 0.00686713
# [5000]	training's l2: 0.00248912	valid_1's l2: 0.0066525
# [6000]	training's l2: 0.00205912	valid_1's l2: 0.0065257
# [7000]	training's l2: 0.00173561	valid_1's l2: 0.00643938
# [8000]	training's l2: 0.00146862	valid_1's l2: 0.00636612
# [9000]	training's l2: 0.00124881	valid_1's l2: 0.00631919
# Early stopping, best iteration is:
# [8813]	training's l2: 0.00128481	valid_1's l2: 0.0063166
# [('ts', 8565), ('N_QY_ORP', 8261), ('N_HYC_DO', 7966), ('B_HYC_DO', 7768), ('B_HYC_MLSS', 7387), ('N_HYC_MLSS', 6783), ('N_HYC_NH4', 6709), ('CS_COD', 6538), ('B_CS_MQ_SSLL', 6027), ('B_HYC_XD', 5947), ('JS_LL', 5883), ('B_HYC_JS_DO', 5809), ('JS_COD', 5741), ('N_HYC_XD', 5606), ('CS_TN', 5603), ('CS_NH3', 5489), ('minute', 5320), ('JS_NH3', 5257), ('CS_LL', 5236), ('N_CS_MQ_SSLL', 4927)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623]
# ************************************ 4 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00742884	valid_1's l2: 0.0144742
# [2000]	training's l2: 0.00496535	valid_1's l2: 0.0128735
# [3000]	training's l2: 0.00375838	valid_1's l2: 0.0121977
# [4000]	training's l2: 0.00297561	valid_1's l2: 0.0118199
# [5000]	training's l2: 0.00241759	valid_1's l2: 0.0115047
# [6000]	training's l2: 0.00200005	valid_1's l2: 0.0113235
# [7000]	training's l2: 0.00167852	valid_1's l2: 0.0112063
# [8000]	training's l2: 0.00142056	valid_1's l2: 0.0110993
# Early stopping, best iteration is:
# [8550]	training's l2: 0.00130167	valid_1's l2: 0.011058
# [('ts', 8465), ('N_QY_ORP', 8113), ('N_HYC_DO', 7640), ('B_HYC_DO', 7389), ('B_HYC_MLSS', 6847), ('N_HYC_MLSS', 6632), ('N_HYC_NH4', 6593), ('CS_COD', 6218), ('B_CS_MQ_SSLL', 5766), ('B_HYC_JS_DO', 5712), ('JS_COD', 5682), ('JS_LL', 5668), ('B_HYC_XD', 5630), ('minute', 5494), ('CS_TN', 5445), ('N_HYC_XD', 5348), ('CS_NH3', 5264), ('CS_LL', 5048), ('JS_NH3', 5005), ('N_CS_MQ_SSLL', 4967)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068]
# ************************************ 5 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00770455	valid_1's l2: 0.00999474
# [2000]	training's l2: 0.00517593	valid_1's l2: 0.00879612
# [3000]	training's l2: 0.00384211	valid_1's l2: 0.00819162
# [4000]	training's l2: 0.00302813	valid_1's l2: 0.00791357
# [5000]	training's l2: 0.00246036	valid_1's l2: 0.00773026
# [6000]	training's l2: 0.00204064	valid_1's l2: 0.00757462
# [7000]	training's l2: 0.00170834	valid_1's l2: 0.00745163
# [8000]	training's l2: 0.00144887	valid_1's l2: 0.00737945
# [9000]	training's l2: 0.00123257	valid_1's l2: 0.00728664
# Early stopping, best iteration is:
# [9549]	training's l2: 0.00112979	valid_1's l2: 0.00725485
# [('ts', 9426), ('N_QY_ORP', 8947), ('N_HYC_DO', 8600), ('B_HYC_DO', 8322), ('B_HYC_MLSS', 7634), ('N_HYC_NH4', 7418), ('N_HYC_MLSS', 7184), ('CS_COD', 6931), ('JS_LL', 6763), ('B_HYC_JS_DO', 6459), ('B_HYC_XD', 6400), ('B_CS_MQ_SSLL', 6311), ('JS_COD', 6239), ('N_HYC_XD', 6211), ('minute', 5976), ('CS_TN', 5966), ('CS_NH3', 5944), ('CS_LL', 5856), ('JS_NH3', 5664), ('N_CS_MQ_SSLL', 5319)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428]
# ************************************ 6 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00771657	valid_1's l2: 0.0105207
# [2000]	training's l2: 0.00522139	valid_1's l2: 0.00916954
# [3000]	training's l2: 0.0039121	valid_1's l2: 0.0085457
# [4000]	training's l2: 0.00308031	valid_1's l2: 0.00817275
# [5000]	training's l2: 0.00250723	valid_1's l2: 0.00792409
# [6000]	training's l2: 0.00207462	valid_1's l2: 0.00771279
# [7000]	training's l2: 0.00172997	valid_1's l2: 0.00761284
# [8000]	training's l2: 0.00146166	valid_1's l2: 0.00754974
# [9000]	training's l2: 0.00124482	valid_1's l2: 0.00748527
# [10000]	training's l2: 0.00106712	valid_1's l2: 0.00743469
# [11000]	training's l2: 0.000918268	valid_1's l2: 0.00739221
# [12000]	training's l2: 0.000793594	valid_1's l2: 0.0073711
# Early stopping, best iteration is:
# [11899]	training's l2: 0.000805349	valid_1's l2: 0.00736781
# [('ts', 11309), ('N_HYC_DO', 10624), ('N_QY_ORP', 10576), ('B_HYC_DO', 10510), ('B_HYC_MLSS', 9583), ('N_HYC_MLSS', 9022), ('N_HYC_NH4', 8978), ('B_HYC_XD', 8535), ('JS_LL', 8481), ('B_CS_MQ_SSLL', 8441), ('B_HYC_JS_DO', 8383), ('CS_COD', 8148), ('N_HYC_XD', 7924), ('CS_LL', 7792), ('minute', 7469), ('JS_COD', 7307), ('CS_TN', 7172), ('CS_NH3', 7115), ('N_CS_MQ_SSLL', 7078), ('JS_NH3', 6750)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029]
# ************************************ 7 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00765039	valid_1's l2: 0.00932564
# [2000]	training's l2: 0.0051057	valid_1's l2: 0.00808503
# [3000]	training's l2: 0.00380078	valid_1's l2: 0.00751333
# [4000]	training's l2: 0.00299625	valid_1's l2: 0.0072262
# [5000]	training's l2: 0.00242634	valid_1's l2: 0.00698958
# [6000]	training's l2: 0.00201041	valid_1's l2: 0.00688648
# [7000]	training's l2: 0.00168405	valid_1's l2: 0.00679006
# [8000]	training's l2: 0.00142083	valid_1's l2: 0.00671831
# [9000]	training's l2: 0.00120909	valid_1's l2: 0.00666566
# [10000]	training's l2: 0.00103884	valid_1's l2: 0.00663523
# [11000]	training's l2: 0.000892201	valid_1's l2: 0.00660233
# Early stopping, best iteration is:
# [11556]	training's l2: 0.000820645	valid_1's l2: 0.00658583
# [('ts', 10942), ('N_QY_ORP', 10610), ('N_HYC_DO', 10387), ('B_HYC_DO', 10013), ('B_HYC_MLSS', 9361), ('N_HYC_NH4', 8991), ('N_HYC_MLSS', 8837), ('B_CS_MQ_SSLL', 8236), ('B_HYC_JS_DO', 8129), ('B_HYC_XD', 7959), ('CS_COD', 7877), ('JS_LL', 7833), ('N_HYC_XD', 7763), ('CS_LL', 7453), ('minute', 7198), ('JS_COD', 7153), ('CS_TN', 7108), ('CS_NH3', 6935), ('N_CS_MQ_SSLL', 6909), ('JS_NH3', 6469)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029, 1220.8302785678975]
# ************************************ 8 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.0076503	valid_1's l2: 0.00938698
# [2000]	training's l2: 0.00512838	valid_1's l2: 0.00860978
# [3000]	training's l2: 0.00384481	valid_1's l2: 0.00815838
# [4000]	training's l2: 0.00304582	valid_1's l2: 0.00790186
# [5000]	training's l2: 0.00247294	valid_1's l2: 0.00771709
# [6000]	training's l2: 0.00205327	valid_1's l2: 0.00756572
# [7000]	training's l2: 0.00172318	valid_1's l2: 0.00751117
# Early stopping, best iteration is:
# [6876]	training's l2: 0.00175941	valid_1's l2: 0.00749819
# [('ts', 7343), ('N_QY_ORP', 6677), ('N_HYC_DO', 6245), ('B_HYC_DO', 5957), ('B_HYC_MLSS', 5567), ('N_HYC_MLSS', 5349), ('CS_COD', 5345), ('N_HYC_NH4', 5313), ('JS_COD', 4715), ('JS_LL', 4524), ('B_CS_MQ_SSLL', 4523), ('CS_TN', 4489), ('B_HYC_XD', 4474), ('JS_NH3', 4381), ('CS_NH3', 4307), ('B_HYC_JS_DO', 4229), ('minute', 4151), ('N_HYC_XD', 4115), ('CS_LL', 3732), ('N_CS_MQ_SSLL', 3471)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029, 1220.8302785678975, 1432.3705232624009]
# ************************************ 9 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00753143	valid_1's l2: 0.0156797
# [2000]	training's l2: 0.00510793	valid_1's l2: 0.0146197
# [3000]	training's l2: 0.00386669	valid_1's l2: 0.0139265
# Early stopping, best iteration is:
# [3779]	training's l2: 0.00320595	valid_1's l2: 0.0135648
# [('ts', 4454), ('N_QY_ORP', 3916), ('N_HYC_DO', 3550), ('CS_COD', 3471), ('B_HYC_DO', 3337), ('B_HYC_MLSS', 3062), ('N_HYC_NH4', 2965), ('JS_COD', 2824), ('N_HYC_MLSS', 2814), ('CS_TN', 2754), ('CS_NH3', 2634), ('JS_NH3', 2463), ('N_HYC_XD', 2259), ('JS_LL', 2249), ('B_HYC_JS_DO', 2214), ('B_CS_MQ_SSLL', 2203), ('B_HYC_XD', 2200), ('minute', 2111), ('CS_LL', 1587), ('N_CS_MQ_SSLL', 1376)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029, 1220.8302785678975, 1432.3705232624009, 1546.974736306065]
# ************************************ 10 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00752991	valid_1's l2: 0.0119344
# [2000]	training's l2: 0.00507735	valid_1's l2: 0.0105745
# [3000]	training's l2: 0.00382106	valid_1's l2: 0.00990158
# [4000]	training's l2: 0.00304072	valid_1's l2: 0.00959153
# [5000]	training's l2: 0.00246825	valid_1's l2: 0.00936206
# [6000]	training's l2: 0.00203707	valid_1's l2: 0.00914739
# [7000]	training's l2: 0.00170591	valid_1's l2: 0.00901301
# [8000]	training's l2: 0.0014452	valid_1's l2: 0.00889905
# [9000]	training's l2: 0.00122998	valid_1's l2: 0.0088202
# [10000]	training's l2: 0.00105304	valid_1's l2: 0.00873802
# [11000]	training's l2: 0.000905377	valid_1's l2: 0.00867776
# [12000]	training's l2: 0.000781429	valid_1's l2: 0.00864049
# Early stopping, best iteration is:
# [11968]	training's l2: 0.000784878	valid_1's l2: 0.00863894
# [('ts', 11287), ('N_HYC_DO', 10604), ('B_HYC_DO', 10523), ('N_QY_ORP', 10493), ('B_HYC_MLSS', 9524), ('N_HYC_NH4', 9281), ('N_HYC_MLSS', 9219), ('B_CS_MQ_SSLL', 8638), ('B_HYC_JS_DO', 8466), ('B_HYC_XD', 8433), ('JS_LL', 8430), ('CS_COD', 8129), ('N_HYC_XD', 8065), ('CS_LL', 8017), ('minute', 7589), ('JS_COD', 7355), ('CS_TN', 7251), ('N_CS_MQ_SSLL', 7207), ('CS_NH3', 7127), ('JS_NH3', 6572)]
# [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029, 1220.8302785678975, 1432.3705232624009, 1546.974736306065, 1329.33625400042]
# s_scotrainre_list: [1552.3658769487379, 1388.0937554803734, 1354.9401447481623, 1302.2242757212068, 1333.4989974261428, 1143.6966905220029, 1220.8302785678975, 1432.3705232624009, 1546.974736306065, 1329.33625400042]
# s_score_mean: 1360.433153298341
# s_score_std: 122.12722714829968
# ************************************ 1 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00709021	valid_1's l2: 0.0156186
# [2000]	training's l2: 0.00485528	valid_1's l2: 0.0145976
# [3000]	training's l2: 0.00368161	valid_1's l2: 0.0141347
# [4000]	training's l2: 0.00292594	valid_1's l2: 0.0139066
# Early stopping, best iteration is:
# [3864]	training's l2: 0.00301016	valid_1's l2: 0.013888
# [('ts', 4326), ('N_QY_ORP', 4083), ('N_HYC_DO', 3903), ('CS_COD', 3317), ('B_HYC_DO', 3143), ('N_HYC_MLSS', 3059), ('B_HYC_MLSS', 3032), ('N_HYC_NH4', 2934), ('JS_NH3', 2915), ('CS_NH3', 2812), ('JS_COD', 2787), ('CS_TN', 2735), ('B_CS_MQ_SSLL', 2381), ('JS_LL', 2334), ('N_HYC_XD', 2271), ('B_HYC_JS_DO', 2203), ('B_HYC_XD', 2190), ('minute', 2061), ('CS_LL', 1729), ('N_CS_MQ_SSLL', 1469)]
# [1291.2217039848586]
# ************************************ 2 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.0072764	valid_1's l2: 0.0115021
# [2000]	training's l2: 0.00497627	valid_1's l2: 0.0103731
# [3000]	training's l2: 0.00377057	valid_1's l2: 0.00973103
# [4000]	training's l2: 0.00298423	valid_1's l2: 0.00945799
# [5000]	training's l2: 0.00243323	valid_1's l2: 0.00928654
# [6000]	training's l2: 0.00201256	valid_1's l2: 0.00915358
# [7000]	training's l2: 0.00168425	valid_1's l2: 0.00905667
# Early stopping, best iteration is:
# [7744]	training's l2: 0.00148408	valid_1's l2: 0.00900857
# [('ts', 7544), ('N_HYC_DO', 7485), ('N_QY_ORP', 7434), ('B_HYC_DO', 6572), ('N_HYC_MLSS', 6393), ('B_HYC_MLSS', 6185), ('N_HYC_NH4', 6107), ('CS_COD', 5463), ('JS_LL', 5351), ('B_CS_MQ_SSLL', 5240), ('B_HYC_XD', 5172), ('N_HYC_XD', 5027), ('CS_TN', 4949), ('JS_COD', 4924), ('B_HYC_JS_DO', 4881), ('JS_NH3', 4861), ('CS_NH3', 4810), ('minute', 4542), ('CS_LL', 4348), ('N_CS_MQ_SSLL', 4160)]
# [1291.2217039848586, 1087.7955111528925]
# ************************************ 3 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00739653	valid_1's l2: 0.00857705
# [2000]	training's l2: 0.00500999	valid_1's l2: 0.00759384
# [3000]	training's l2: 0.00378301	valid_1's l2: 0.00712453
# [4000]	training's l2: 0.00300162	valid_1's l2: 0.00690585
# Early stopping, best iteration is:
# [4296]	training's l2: 0.00282633	valid_1's l2: 0.00683174
# [('ts', 4538), ('N_QY_ORP', 4373), ('N_HYC_DO', 4288), ('CS_COD', 3806), ('B_HYC_DO', 3549), ('N_HYC_MLSS', 3457), ('N_HYC_NH4', 3340), ('B_HYC_MLSS', 3330), ('JS_COD', 3082), ('JS_NH3', 3050), ('CS_TN', 3006), ('CS_NH3', 2920), ('B_CS_MQ_SSLL', 2653), ('N_HYC_XD', 2635), ('JS_LL', 2593), ('B_HYC_XD', 2486), ('minute', 2461), ('B_HYC_JS_DO', 2429), ('CS_LL', 2040), ('N_CS_MQ_SSLL', 1804)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268]
# ************************************ 4 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.007148	valid_1's l2: 0.0140915
# [2000]	training's l2: 0.00490497	valid_1's l2: 0.0126356
# [3000]	training's l2: 0.00371677	valid_1's l2: 0.0119725
# [4000]	training's l2: 0.00294883	valid_1's l2: 0.0116049
# [5000]	training's l2: 0.00240012	valid_1's l2: 0.0113497
# [6000]	training's l2: 0.00198876	valid_1's l2: 0.0111507
# [7000]	training's l2: 0.00166841	valid_1's l2: 0.011032
# [8000]	training's l2: 0.00141152	valid_1's l2: 0.0109447
# [9000]	training's l2: 0.00119898	valid_1's l2: 0.010844
# [10000]	training's l2: 0.00102617	valid_1's l2: 0.0107644
# [11000]	training's l2: 0.000883947	valid_1's l2: 0.0106939
# [12000]	training's l2: 0.000764353	valid_1's l2: 0.0106568
# [13000]	training's l2: 0.000662789	valid_1's l2: 0.0106175
# [14000]	training's l2: 0.000575251	valid_1's l2: 0.0105894
# [15000]	training's l2: 0.000501115	valid_1's l2: 0.0105538
# [16000]	training's l2: 0.000438004	valid_1's l2: 0.0105344
# Early stopping, best iteration is:
# [16412]	training's l2: 0.000414456	valid_1's l2: 0.0105199
# [('N_HYC_DO', 15060), ('ts', 13945), ('B_HYC_DO', 13905), ('N_QY_ORP', 13803), ('N_HYC_MLSS', 12968), ('B_HYC_MLSS', 12695), ('N_HYC_NH4', 12619), ('B_HYC_JS_DO', 12327), ('B_CS_MQ_SSLL', 12116), ('B_HYC_XD', 12109), ('JS_LL', 11788), ('N_HYC_XD', 11759), ('CS_LL', 11745), ('N_CS_MQ_SSLL', 11542), ('minute', 10653), ('CS_COD', 9860), ('CS_TN', 9294), ('JS_COD', 9201), ('JS_NH3', 9159), ('CS_NH3', 9152)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152]
# ************************************ 5 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00739726	valid_1's l2: 0.0096588
# [2000]	training's l2: 0.00501277	valid_1's l2: 0.00860538
# [3000]	training's l2: 0.00378498	valid_1's l2: 0.00814354
# [4000]	training's l2: 0.00299881	valid_1's l2: 0.00784134
# Early stopping, best iteration is:
# [4461]	training's l2: 0.00272305	valid_1's l2: 0.00776025
# [('ts', 4725), ('N_QY_ORP', 4723), ('N_HYC_DO', 4493), ('CS_COD', 4029), ('B_HYC_DO', 3606), ('B_HYC_MLSS', 3546), ('N_HYC_MLSS', 3480), ('N_HYC_NH4', 3447), ('JS_COD', 3151), ('JS_NH3', 3147), ('CS_NH3', 3104), ('CS_TN', 3027), ('B_CS_MQ_SSLL', 2837), ('N_HYC_XD', 2799), ('JS_LL', 2775), ('B_HYC_XD', 2595), ('minute', 2502), ('B_HYC_JS_DO', 2426), ('CS_LL', 2079), ('N_CS_MQ_SSLL', 1778)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548]
# ************************************ 6 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00735536	valid_1's l2: 0.0101769
# [2000]	training's l2: 0.00501757	valid_1's l2: 0.00882366
# [3000]	training's l2: 0.00380692	valid_1's l2: 0.00823803
# [4000]	training's l2: 0.00302275	valid_1's l2: 0.00794189
# [5000]	training's l2: 0.00246765	valid_1's l2: 0.00777126
# [6000]	training's l2: 0.00205167	valid_1's l2: 0.00759788
# [7000]	training's l2: 0.00171705	valid_1's l2: 0.00747858
# [8000]	training's l2: 0.00145226	valid_1's l2: 0.0074045
# [9000]	training's l2: 0.00123735	valid_1's l2: 0.0073429
# Early stopping, best iteration is:
# [9333]	training's l2: 0.00117537	valid_1's l2: 0.00732351
# [('N_HYC_DO', 9045), ('ts', 9040), ('N_QY_ORP', 8315), ('B_HYC_DO', 7974), ('N_HYC_MLSS', 7529), ('B_HYC_MLSS', 7179), ('N_HYC_NH4', 7114), ('CS_COD', 6593), ('JS_LL', 6583), ('B_CS_MQ_SSLL', 6429), ('B_HYC_XD', 6368), ('B_HYC_JS_DO', 6348), ('N_HYC_XD', 6141), ('minute', 5884), ('CS_TN', 5816), ('JS_NH3', 5794), ('JS_COD', 5675), ('CS_NH3', 5563), ('CS_LL', 5558), ('N_CS_MQ_SSLL', 5363)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046]
# ************************************ 7 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00726078	valid_1's l2: 0.0085611
# [2000]	training's l2: 0.00493063	valid_1's l2: 0.00762065
# [3000]	training's l2: 0.00370258	valid_1's l2: 0.0071179
# [4000]	training's l2: 0.00293614	valid_1's l2: 0.00691674
# [5000]	training's l2: 0.00238014	valid_1's l2: 0.00672057
# [6000]	training's l2: 0.00196792	valid_1's l2: 0.00662421
# [7000]	training's l2: 0.00165146	valid_1's l2: 0.00655466
# [8000]	training's l2: 0.00139293	valid_1's l2: 0.00648912
# [9000]	training's l2: 0.00118655	valid_1's l2: 0.00644929
# [10000]	training's l2: 0.00101559	valid_1's l2: 0.00641864
# [11000]	training's l2: 0.000877022	valid_1's l2: 0.00639168
# [12000]	training's l2: 0.000757237	valid_1's l2: 0.00636484
# Early stopping, best iteration is:
# [12080]	training's l2: 0.000748501	valid_1's l2: 0.00636269
# [('N_HYC_DO', 11168), ('ts', 10992), ('N_QY_ORP', 10788), ('B_HYC_DO', 10315), ('N_HYC_MLSS', 9721), ('B_HYC_MLSS', 9536), ('N_HYC_NH4', 9313), ('B_CS_MQ_SSLL', 8843), ('B_HYC_XD', 8591), ('B_HYC_JS_DO', 8551), ('JS_LL', 8350), ('N_HYC_XD', 8171), ('CS_LL', 7961), ('CS_COD', 7737), ('minute', 7529), ('CS_TN', 7349), ('N_CS_MQ_SSLL', 7339), ('CS_NH3', 7201), ('JS_NH3', 7085), ('JS_COD', 7078)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046, 978.7237866961012]
# ************************************ 8 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00734719	valid_1's l2: 0.00904373
# [2000]	training's l2: 0.00501318	valid_1's l2: 0.00849957
# [3000]	training's l2: 0.00381768	valid_1's l2: 0.00808314
# [4000]	training's l2: 0.00303283	valid_1's l2: 0.00785057
# [5000]	training's l2: 0.0024663	valid_1's l2: 0.00770714
# Early stopping, best iteration is:
# [4892]	training's l2: 0.0025201	valid_1's l2: 0.00767495
# [('ts', 5113), ('N_QY_ORP', 4954), ('N_HYC_DO', 4876), ('CS_COD', 4166), ('B_HYC_DO', 4074), ('N_HYC_NH4', 3913), ('B_HYC_MLSS', 3862), ('N_HYC_MLSS', 3830), ('JS_NH3', 3518), ('CS_TN', 3332), ('JS_COD', 3246), ('CS_NH3', 3240), ('N_HYC_XD', 3007), ('JS_LL', 3006), ('B_CS_MQ_SSLL', 3003), ('minute', 2886), ('B_HYC_XD', 2881), ('B_HYC_JS_DO', 2856), ('CS_LL', 2439), ('N_CS_MQ_SSLL', 2135)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046, 978.7237866961012, 1208.2113250123166]
# ************************************ 9 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00709459	valid_1's l2: 0.0151001
# [2000]	training's l2: 0.0048852	valid_1's l2: 0.0141565
# [3000]	training's l2: 0.00373004	valid_1's l2: 0.0136024
# [4000]	training's l2: 0.00296673	valid_1's l2: 0.0133712
# [5000]	training's l2: 0.00242423	valid_1's l2: 0.0131867
# [6000]	training's l2: 0.00201376	valid_1's l2: 0.0130143
# Early stopping, best iteration is:
# [5913]	training's l2: 0.00204638	valid_1's l2: 0.0129954
# [('ts', 6002), ('N_HYC_DO', 5729), ('N_QY_ORP', 5654), ('B_HYC_DO', 4875), ('N_HYC_NH4', 4702), ('B_HYC_MLSS', 4669), ('CS_COD', 4631), ('N_HYC_MLSS', 4546), ('CS_TN', 4055), ('JS_COD', 4021), ('JS_LL', 4020), ('B_CS_MQ_SSLL', 3962), ('JS_NH3', 3903), ('CS_NH3', 3777), ('B_HYC_JS_DO', 3741), ('N_HYC_XD', 3713), ('B_HYC_XD', 3663), ('minute', 3503), ('CS_LL', 3066), ('N_CS_MQ_SSLL', 2853)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046, 978.7237866961012, 1208.2113250123166, 1255.806543839159]
# ************************************ 10 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00727213	valid_1's l2: 0.0114576
# [2000]	training's l2: 0.00497847	valid_1's l2: 0.0104741
# [3000]	training's l2: 0.00376455	valid_1's l2: 0.00976285
# [4000]	training's l2: 0.00299557	valid_1's l2: 0.00943493
# [5000]	training's l2: 0.00244787	valid_1's l2: 0.00919775
# [6000]	training's l2: 0.00202353	valid_1's l2: 0.00899885
# [7000]	training's l2: 0.00169751	valid_1's l2: 0.00888518
# [8000]	training's l2: 0.00143479	valid_1's l2: 0.00876364
# [9000]	training's l2: 0.00122184	valid_1's l2: 0.00864579
# [10000]	training's l2: 0.00104493	valid_1's l2: 0.00857189
# [11000]	training's l2: 0.000899693	valid_1's l2: 0.00852688
# [12000]	training's l2: 0.00077989	valid_1's l2: 0.00847881
# [13000]	training's l2: 0.000674646	valid_1's l2: 0.00844437
# Early stopping, best iteration is:
# [13406]	training's l2: 0.000635858	valid_1's l2: 0.00843477
# [('N_HYC_DO', 12325), ('ts', 11797), ('N_QY_ORP', 11443), ('B_HYC_DO', 11344), ('N_HYC_MLSS', 10642), ('B_HYC_MLSS', 10579), ('N_HYC_NH4', 10448), ('B_HYC_JS_DO', 9978), ('B_CS_MQ_SSLL', 9726), ('B_HYC_XD', 9669), ('JS_LL', 9613), ('N_HYC_XD', 9404), ('CS_LL', 9148), ('N_CS_MQ_SSLL', 8687), ('CS_COD', 8565), ('minute', 8418), ('CS_TN', 8101), ('JS_NH3', 7767), ('CS_NH3', 7729), ('JS_COD', 7664)]
# [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046, 978.7237866961012, 1208.2113250123166, 1255.806543839159, 1113.6708425962688]
# s_scotrainre_list: [1291.2217039848586, 1087.7955111528925, 1163.5123361279268, 1071.96424301152, 1121.2998302260548, 988.7262028135046, 978.7237866961012, 1208.2113250123166, 1255.806543839159, 1113.6708425962688]
# s_score_mean: 1128.0932325460603
# s_score_std: 98.67012491477625

# %%
# 特征重要性
Feass0.groupby(['feas'])['sorce'].mean().sort_values(ascending=False).reset_index(),\
Feass1.groupby(['feas'])['sorce'].mean().sort_values(ascending=False).reset_index()
# Out:
# (            feas   sorce
#  0             ts  8497.6
#  1       N_QY_ORP  7950.9
#  2       N_HYC_DO  7659.3
#  3       B_HYC_DO  7434.1
#  4     B_HYC_MLSS  6867.1
#  5      N_HYC_NH4  6542.4
#  6     N_HYC_MLSS  6524.3
#  7         CS_COD  6202.8
#  8   B_CS_MQ_SSLL  5801.9
#  9          JS_LL  5752.0
#  10      B_HYC_XD  5702.0
#  11   B_HYC_JS_DO  5666.5
#  12        JS_COD  5542.2
#  13      N_HYC_XD  5451.4
#  14         CS_TN  5392.0
#  15        CS_NH3  5290.4
#  16        minute  5206.7
#  17         CS_LL  5089.1
#  18        JS_NH3  5017.5
#  19  N_CS_MQ_SSLL  4714.4
#  20     B_HYC_NH4  2026.7
#  21       weekday  1641.7
#  22          hour  1484.7
#  23        isnull    34.8,
#              feas   sorce
#  0       N_HYC_DO  7837.2
#  1             ts  7802.2
#  2       N_QY_ORP  7557.0
#  3       B_HYC_DO  6935.7
#  4     N_HYC_MLSS  6562.5
#  5     B_HYC_MLSS  6461.3
#  6      N_HYC_NH4  6393.7
#  7         CS_COD  5816.7
#  8   B_CS_MQ_SSLL  5719.0
#  9          JS_LL  5641.3
#  10   B_HYC_JS_DO  5574.0
#  11      B_HYC_XD  5572.4
#  12      N_HYC_XD  5492.7
#  13         CS_TN  5166.4
#  14        JS_NH3  5119.9
#  15        JS_COD  5082.9
#  16        minute  5043.9
#  17        CS_NH3  5030.8
#  18         CS_LL  5011.3
#  19  N_CS_MQ_SSLL  4713.0
#  20     B_HYC_NH4  2051.9
#  21       weekday  1595.5
#  22          hour  1392.7
#  23        isnull    27.5)

# %%
# 线下得分

1/(1+(scores0+scores1)/2)*1000
# Out:
# 0.8030430881469699

# %%
sub = pd.read_csv('sample_submission.csv')
sub['Label1'] = np.expm1(lgb_test0)
sub['Label2'] = np.expm1(lgb_test1)
sub.to_csv('0928_lgb_base_0.8030430881469699.csv', index=False)
